# %% [markdown]
# # LAB 2: Probability Distributions and Statistical Data Visualization
#
# In this lab you will use python to study the following topics:
#
# - How to sample from different distributions functions.
# - Calculate arthemitic mean, sample variance, and sample standard deviation for different distributions functions.
# - Statistical data visualization using seaborn library

# %% [markdown]
# # First: you should run this cell

# %%
# Make all numpy available via shorter 'np' prefix
import numpy as np
from scipy import stats


# matplotlib library
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# # Problem 1
# a) Use the numpy function [numpy.random.normal](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html) to generate a standard Gaussian random variable $X$ (zero mean and unit variance).
#
# - Use histogram to plot the estimated PDF of the random variable $X$
# - Compute the true "analytical" PDF -using the equation- of $X$ . Plot the true PDF on the top of the histogram figure.
# - Calculate the sample mean and the sample variance.

# %% [markdown]
# ### True/Analytical PDF
# ![image.png](attachment:image.png)

# %% [markdown]
# ## using `numpy`

# %%
#type your code here:
mu=0
sigma=1

ff=np.random.normal(loc=mu, scale=sigma, size=1000)
print("Sample mean:", ff.mean())
print("Sample variance:", ff.var())

plt.hist(ff, bins=20, density=True)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = (1/np.sqrt(2 * np.pi * sigma**2)) * np.exp(-0.5 * ((x - mu)**2) / sigma**2)


plt.plot(x, p, color='red')
plt.grid(True)
plt.show()
# Out:
# Sample mean: -0.060555020269779325
# Sample variance: 0.9795749718296722

# %% [markdown]
# ## using `scipy`

# %%
#type your code here:


print("Sample mean:", np.mean(ff))
print("Sample variance:", np.var(ff))

plt.hist(ff, bins=20, density=True)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

p = stats.norm.pdf(x, loc=0, scale=1)

plt.plot(x, p, color='red')

plt.grid(True)
plt.show()
# Out:
# Sample mean: -0.060555020269779325
# Sample variance: 0.9795749718296722

# %% [markdown]
# - Compute the true "analytical" PDF using [scipy.stats.norm.pdf](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html). Plot the true PDF on the top of the histogram figure.
# - Compute the CDF using [scipy.stats.norm.cdf](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html), then plot it.

# %%
#type your code here:

plt.hist(ff, bins=20, density=True)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

p = stats.norm.pdf(x, loc=0, scale=1)
c = stats.norm.cdf(x, loc=0, scale=1)

plt.plot(x, p, color='red')
plt.plot(x, c, color='orange')
plt.grid(True)
plt.legend(['PDF', 'CDF','Histogram'])
plt.show()

# %% [markdown]
# b) Repeat (a) for a Gaussian random variable $Y$ with $mean=3$ and $variance=4$.

# %%
#type your code here:
mu=3
sigma=np.sqrt(4)

ff=np.random.normal(loc=mu, scale=sigma, size=1000)

print("Sample mean:", ff.mean())
print("Sample variance:", ff.var())

plt.hist(ff, bins=20, density=True)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

p = stats.norm.pdf(x, loc=mu, scale=sigma)

plt.plot(x, p, color='red')

plt.grid(True)
plt.show()
# Out:
# Sample mean: 2.986588081728399
# Sample variance: 3.935431157146068

# %%
#type your code here:

plt.hist(ff, bins=20, density=True)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

p = stats.norm.pdf(x, loc=mu, scale=sigma)
c = stats.norm.cdf(x, loc=mu, scale=sigma)

plt.plot(x, p, color='red')
plt.plot(x, c, color='orange')
plt.grid(True)
plt.legend(['PDF', 'CDF','Histogram'])
plt.show()

# %% [markdown]
# C) Repeat (a) for an exponential random variable with $\lambda = 1$ using [numpy.random.exponential](https://numpy.org/doc/stable/reference/random/generated/numpy.random.exponential.html), and [scipy.stats.expon](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.expon.html#scipy.stats.expon)

# %%
#type your code here:

ff=np.random.exponential(scale=1, size=1000)

print("Sample mean:", ff.mean())
print("Sample variance:", ff.var())

plt.hist(ff, bins=20, density=True)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

p = stats.expon.pdf(x, scale=1)

plt.plot(x, p, color='red')

plt.grid(True)
plt.show()
# Out:
# Sample mean: 0.9631826110328473
# Sample variance: 0.9010551257623585

# %%
#type your code here:

plt.hist(ff, bins=20, density=True)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

p = stats.expon.pdf(x, scale=1)
c = stats.expon.cdf(x, scale=1)

plt.plot(x, p, color='red')
plt.plot(x, c, color='orange')
plt.grid(True)
plt.legend(['PDF', 'CDF','Histogram'])
plt.show()

# %% [markdown]
# d) Repeat (a) for an exponential random variable with $\lambda = 0.5$

# %%
#type your code here:

ff=np.random.exponential(scale=2, size=1000)

print("Sample mean:", ff.mean())
print("Sample variance:", ff.var())

plt.hist(ff, bins=20, density=True)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

p = stats.expon.pdf(x, scale=2)

plt.plot(x, p, color='red')

plt.grid(True)
plt.show()
# Out:
# Sample mean: 1.9886764192370097
# Sample variance: 3.9011847795753765

# %%
#type your code here:

plt.hist(ff, bins=20, density=True)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

p = stats.expon.pdf(x, scale=2)
c = stats.expon.cdf(x, scale=2)
plt.plot(x, p, color='red')
plt.plot(x, c, color='orange')
plt.grid(True)
plt.legend(['PDF', 'CDF','Histogram'])
plt.show()

# %% [markdown]
# e) Repeat for an binomial random variable with $n = 5$ and $p = 0.5$

# %%
#type your code here:
n=5
p=0.5


ff=np.random.binomial(n, p, size=1000)

print("Sample mean:", np.mean(ff))
print("Sample variance:", np.var(ff))

bins = np.arange(0, n+1) 
plt.hist(ff, bins=bins, density=True)

x = np.arange(0, n+1)

pmf = stats.binom.pmf(x, n, p)

markerline, stemlines, baseline = plt.stem(
    x, pmf,
    linefmt='r-',
    markerfmt=' ',
    basefmt=' '
)

plt.legend(['Histogram', 'PMF'])
plt.grid(True)
plt.show()
# Out:
# Sample mean: 2.485
# Sample variance: 1.161775

# %%
#type your code here:
n=5
p=0.5


x = np.arange(0, n+1)

pmf = stats.binom.pmf(x, n, p)
cdf= stats.binom.cdf(x, n, p)

markerline, stemlines, baseline = plt.stem(
    x, pmf,
    linefmt='r-',
    markerfmt=' ',
    basefmt=' '
)

plt.step(x, cdf, where='post', color='blue')



plt.legend(['CDF', 'PMF'])

plt.grid(True)
plt.show()

# %% [markdown]
# f) Repeat for an binomial random variable with $n = 20$ and $p = 0.5$

# %%
#type your code here:
n=20
p=0.5


ff=np.random.binomial(n, p, size=1000)

print("Sample mean:", np.mean(ff))
print("Sample variance:", np.var(ff))

bins = np.arange(0, n+1) 
plt.hist(ff, bins=bins, density=True)

x = np.arange(0, n+1)

pmf = stats.binom.pmf(x, n, p)

markerline, stemlines, baseline = plt.stem(
    x, pmf,
    linefmt='r-',
    markerfmt=' ',
    basefmt=' '
)

plt.legend(['Histogram', 'PMF'])
plt.grid(True)
plt.show()
# Out:
# Sample mean: 10.003
# Sample variance: 4.696991

# %%
#type your code here:
n=20
p=0.5


x = np.arange(0, n+1)

pmf = stats.binom.pmf(x, n, p)
cdf= stats.binom.cdf(x, n, p)

markerline, stemlines, baseline = plt.stem(
    x, pmf,
    linefmt='r-',
    markerfmt=' ',
    basefmt=' '
)

plt.step(x, cdf, where='post', color='blue')



plt.legend(['CDF', 'PMF'])

plt.grid(True)
plt.show()

# %% [markdown]
# # Problem 2
#
# (a) In this problem, you will use [seaborn](https://seaborn.pydata.org/) for statistical data visualization:
#
# - Load the penguins data `df = sns.load_dataset("penguins")`.
# - Display the first 5 rows of the dataset and use any relevant functions that can help you to understand the data.

# %%
df = sns.load_dataset("penguins")

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# - Use seaborn different plots to explore the data.
# - [pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
#type your code here:
sns.pairplot(df,diag_kind="kde")
plt.show()

# %% [markdown]
# - [heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html) : `sns.heatmap(df.corr(), annot=True)`

# %%
#type your code here:
cols=['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
sns.heatmap(df[cols].corr(), annot=True,)
plt.show()

# %% [markdown]
# - [pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
#type your code here:
sns.pairplot(df, hue="species")
plt.show()

# %%
#type your code here:
sns.pairplot(df, hue="sex")
plt.show()

# %%
#type your code here:
sns.pairplot(df, hue="island")
plt.show()

# %% [markdown]
# - [displot](https://seaborn.pydata.org/generated/seaborn.displot.html)

# %%
#type your code here:
sns.displot(data=df,row='sex',col='species',x='flipper_length_mm',bins=20)
plt.show()

# %%
#type your code here:
sns.displot(data=df,row='sex',col='island',x='flipper_length_mm',bins=20)
plt.show()

# %%
#type your code here:
sns.displot(data=df,row='species',col='island',x='flipper_length_mm',bins=20)
plt.show()

# %% [markdown]
# - [jointplot](https://seaborn.pydata.org/generated/seaborn.jointplot.html)

# %%
#type your code here:
sns.jointplot(data=df, x='bill_length_mm', y='bill_depth_mm', hue='species')
plt.show()

# %%
#type your code here:
sns.jointplot(data=df, x='bill_length_mm', y='bill_depth_mm',kind='hex')
plt.show()

# %% [markdown]
# - [swarmplot](https://seaborn.pydata.org/generated/seaborn.swarmplot.html)

# %%
#type your code here:
sns.swarmplot(x='bill_length_mm', y='sex', data=df,hue='species')
plt.show()

# %% [markdown]
# - [boxplot](https://seaborn.pydata.org/generated/seaborn.boxplot.html)

# %%
#type your code here:
sns.boxplot(x='species', y='body_mass_g', data=df,hue='species')
plt.show()

# %% [markdown]
# #### Another interesting examples:
#
# - https://seaborn.pydata.org/examples/marginal_ticks.html
# - https://seaborn.pydata.org/examples/layered_bivariate_plot.html
# - https://seaborn.pydata.org/examples/joint_kde.html
# - https://seaborn.pydata.org/examples/joint_histogram.html
# - https://seaborn.pydata.org/examples/jitter_stripplot.html
# - https://seaborn.pydata.org/examples/horizontal_boxplot.html

# %% [markdown]
# (b) Exploring iris data:

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.pairplot(df, hue="species")

# %% [markdown]
# # Problem 3: Practicing the Central Limit Theorem
# Use Python to simulate the Central Limit Theorem for the following random i.i.d variables and check that the higher the number of number the variables, the more the mean of subsets behave like a gaussian random variable.

# %%
a = np.random.rand(10000)
n_samples = [10, 50, 100, 500, 1000, 5000, 10000]
sample_size = 50

for i in n_samples:
    plt.figure()
    means = [np.mean(np.random.choice(a, sample_size)) for _ in range(i)]
    sns.histplot(means, bins=30, kde=False, stat="density", edgecolor='black')
    plt.title(f"$n = {i}$")
    plt.xlabel("Sample Mean")
    plt.ylabel("Density")
    plt.show()
