# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("D:\ITI\9 Months Training AI\python\Pandas\database.csv")

# %%
data.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
data.shape
# Out:
# (23412, 21)

# %%
data.columns
# Out:
# Index(['Date', 'Time', 'Latitude', 'Longitude', 'Type', 'Depth', 'Depth Error',
#        'Depth Seismic Stations', 'Magnitude', 'Magnitude Type',
#        'Magnitude Error', 'Magnitude Seismic Stations', 'Azimuthal Gap',
#        'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'ID',
#        'Source', 'Location Source', 'Magnitude Source', 'Status'],
#       dtype='object')

# %%
data.Magnitude
# Out:
# 0        6.0
# 1        5.8
# 2        6.2
# 3        5.8
# 4        5.8
#         ...
# 23407    5.6
# 23408    5.5
# 23409    5.9
# 23410    6.3
# 23411    5.5
# Name: Magnitude, Length: 23412, dtype: float64

# %%
data.describe()
# Out:
#            Latitude     Longitude         Depth  Depth Error  \
# count  23412.000000  23412.000000  23412.000000  4461.000000
# mean       1.679033     39.639961     70.767911     4.993115
# std       30.113183    125.511959    122.651898     4.875184
# min      -77.080000   -179.997000     -1.100000     0.000000
# 25%      -18.653000    -76.349750     14.522500     1.800000
# 50%       -3.568500    103.982000     33.000000     3.500000
# 75%       26.190750    145.026250     54.000000     6.300000
# max       86.005000    179.998000    700.000000    91.295000
#
#        Depth Seismic Stations     Magnitude  Magnitude Error  \
# count             7097.000000  23412.000000       327.000000
# mean               275.364098      5.882531         0.071820
# std                162.141631      0.423066         0.051466
# min                  0.000000      5.500000         0.000000
# 25%                146.000000      5.600000         0.046000
# ...

# %%
#remove duplicate rows
data.drop_duplicates(inplace=True)

# %%
print(type(data.Time))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#count nulls in each column
print(data.isnull().sum())
# Out:
# Date                              0
# Time                              0
# Latitude                          0
# Longitude                         0
# Type                              0
# Depth                             0
# Depth Error                   18951
# Depth Seismic Stations        16315
# Magnitude                         0
# Magnitude Type                    3
# Magnitude Error               23085
# Magnitude Seismic Stations    20848
# Azimuthal Gap                 16113
# Horizontal Distance           21808
# Horizontal Error              22256
# Root Mean Square               6060
# ID                                0
# Source                            0
# Location Source                   0
# Magnitude Source                  0
# Status                            0
# dtype: int64

# %%
data.Date
# Out:
# 0        01/02/1965
# 1        01/04/1965
# 2        01/05/1965
# 3        01/08/1965
# 4        01/09/1965
#             ...
# 23407    12/28/2016
# 23408    12/28/2016
# 23409    12/28/2016
# 23410    12/29/2016
# 23411    12/30/2016
# Name: Date, Length: 23412, dtype: object

# %%
data.Date.describe()
# Out:
# count          23412
# unique         12401
# top       03/11/2011
# freq             128
# Name: Date, dtype: object

# %%
data[data.Date.str.len() == 10]
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
data[data.Date.str.len() == 24]
# Out:
#                            Date                      Time  Latitude  \
# 3378   1975-02-23T02:58:41.000Z  1975-02-23T02:58:41.000Z     8.017
# 7512   1985-04-28T02:53:41.530Z  1985-04-28T02:53:41.530Z   -32.998
# 20650  2011-03-13T02:23:34.520Z  2011-03-13T02:23:34.520Z    36.344
#
#        Longitude        Type  Depth  Depth Error  Depth Seismic Stations  \
# 3378     124.075  Earthquake  623.0          NaN                     NaN
# 7512     -71.766  Earthquake   33.0          NaN                     NaN
# 20650    142.344  Earthquake   10.1         13.9                   289.0
#
#        Magnitude Magnitude Type  ...  Magnitude Seismic Stations  \
# 3378         5.6             MB  ...                         NaN
# 7512         5.6             MW  ...                         NaN
# 20650        5.8            MWC  ...                         NaN
#
#        Azimuthal Gap  Horizontal Distance  Horizontal Error  Root Mean Square  \
# ...

# %%
data.loc[data.Date.str.len() == 24, 'Date'] = data.loc[data.Date.str.len() == 24, 'Date'].str.slice(0,10)

# %%
#convert Date column to datetime
data.Date = pd.to_datetime(data.Date,format='mixed')

# %%
data.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
data.Date
# Out:
# 0       1965-01-02
# 1       1965-01-04
# 2       1965-01-05
# 3       1965-01-08
# 4       1965-01-09
#            ...
# 23407   2016-12-28
# 23408   2016-12-28
# 23409   2016-12-28
# 23410   2016-12-29
# 23411   2016-12-30
# Name: Date, Length: 23412, dtype: datetime64[ns]

# %%
data['Month']=data.Date.dt.month
data['Year']=data.Date.dt.year

# %%
data.Magnitude
# Out:
# 0        6.0
# 1        5.8
# 2        6.2
# 3        5.8
# 4        5.8
#         ...
# 23407    5.6
# 23408    5.5
# 23409    5.9
# 23410    6.3
# 23411    5.5
# Name: Magnitude, Length: 23412, dtype: float64

# %%
data.Magnitude.dtype
# Out:
# dtype('float64')

# %%
data.Magnitude.head()
# Out:
# 0    6.0
# 1    5.8
# 2    6.2
# 3    5.8
# 4    5.8
# Name: Magnitude, dtype: float64

# %%
data.Date.head()
# Out:
# 0   1965-01-02
# 1   1965-01-04
# 2   1965-01-05
# 3   1965-01-08
# 4   1965-01-09
# Name: Date, dtype: datetime64[ns]

# %%
data.Date.describe()
# Out:
# count                            23412
# mean     1993-02-17 21:29:07.411583744
# min                1965-01-02 00:00:00
# 25%                1981-04-10 18:00:00
# 50%                1993-11-30 00:00:00
# 75%                2005-09-09 06:00:00
# max                2016-12-30 00:00:00
# Name: Date, dtype: object

# %%
#print Date.year
data.Date.dt.year.head()
# Out:
# 0    1965
# 1    1965
# 2    1965
# 3    1965
# 4    1965
# Name: Date, dtype: int32

# %%
#ply=t magnitude vs date.month
plt.plot(data.groupby('Month')['Magnitude'].sum())
plt.xlabel('Month')
plt.ylabel('Magnitude')
plt.title('Magnitude vs Month')
plt.show()

# %%
#ply=t magnitude vs date.month
plt.plot(data.groupby('Year')['Magnitude'].sum())
plt.xlabel('Year')
plt.ylabel('Magnitude')
plt.title('Magnitude vs Year')
plt.show()

# %%
data.groupby('Year')['Magnitude'].sum()
# Out:
# Year
# 1965    2038.80
# 1966    1413.47
# 1967    1531.00
# 1968    1853.95
# 1969    1941.02
# 1970    2082.34
# 1971    2305.40
# 1972    2306.20
# 1973    2331.44
# 1974    2104.75
# 1975    2409.49
# 1976    2662.41
# 1977    2458.10
# 1978    2385.60
# 1979    2074.90
# 1980    2034.30
# 1981    1881.95
# 1982    2012.90
# 1983    2662.16
# 1984    2820.52
# 1985    2805.96
# 1986    2840.69
# 1987    2981.30
# 1988    2860.10
# 1989    2804.80
# 1990    3094.41
# 1991    2523.50
# 1992    3135.48
# 1993    2744.20
# 1994    2985.77
# 1995    3489.75
# 1996    3176.80
# 1997    2672.10
# 1998    2277.10
# 1999    2627.21
# 2000    3239.60
# 2001    2604.10
# 2002    2604.60
# 2003    2854.58
# 2004    3340.87
# 2005    3120.90
# 2006    2976.70
# 2007    3578.70
# 2008    3001.70
# 2009    3033.30
# 2010    3303.80
# 2011    4181.50
# 2012    2613.40
# 2013    2711.50
# 2014    2825.72
# 2015    2637.23
# 2016    2763.74
# Name: Magnitude, dtype: float64

# %%
import seaborn as sns

# %%
#magnitude vs year using seaborn
sns.scatterplot(data.groupby('Year')['Magnitude'].sum())
plt.xlabel('Year')
plt.ylabel('Magnitude')
plt.title('Magnitude vs Year')
plt.show()

# %%
#magnitude vs year using seaborn
sns.scatterplot(data.groupby('Month')['Magnitude'].sum())
plt.xlabel('Month')
plt.ylabel('Magnitude')
plt.title('Magnitude vs Month')
plt.show()

# %%
#pandas version
pd.__version__
# Out:
# '2.3.3'
