# %%
import pandas as pd
import numpy as np

# %%
sample_numpy_data = np.array(np.arange(2,26)).reshape((6,4))
dates_index = pd.date_range('20250223', periods=6)
sample_df = pd.DataFrame(sample_numpy_data, index=dates_index, columns=list('ABCD'))
sample_df
# Out:
#              A   B   C   D
# 2025-02-23   2   3   4   5
# 2025-02-24   6   7   8   9
# 2025-02-25  10  11  12  13
# 2025-02-26  14  15  16  17
# 2025-02-27  18  19  20  21
# 2025-02-28  22  23  24  25

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### describe(): a quick statistical summary
# - notice: integer data summarized with floating point numbers

# %%
pd.set_option('display.precision',2)
sample_df.describe(percentiles= [.3, .75])
# Out:
#            A      B      C      D
# count   6.00   6.00   6.00   6.00
# mean   12.00  13.00  14.00  15.00
# std     7.48   7.48   7.48   7.48
# min     2.00   3.00   4.00   5.00
# 30%     8.00   9.00  10.00  11.00
# 50%    12.00  13.00  14.00  15.00
# 75%    17.00  18.00  19.00  20.00
# max    22.00  23.00  24.00  25.00

# %%
sample_df.describe().loc[['mean', 'max', 'min']]
# Out:
#          A     B     C     D
# mean  12.0  13.0  14.0  15.0
# max   22.0  23.0  24.0  25.0
# min    2.0   3.0   4.0   5.0

# %% [markdown]
# ##### column mean

# %%
sample_df.mean()
# Out:
# A    12.0
# B    13.0
# C    14.0
# D    15.0
# dtype: float64

# %% [markdown]
# ##### row mean

# %%
sample_df.mean(1)
# Out:
# 2025-02-23     3.5
# 2025-02-24     7.5
# 2025-02-25    11.5
# 2025-02-26    15.5
# 2025-02-27    19.5
# 2025-02-28    23.5
# Freq: D, dtype: float64
