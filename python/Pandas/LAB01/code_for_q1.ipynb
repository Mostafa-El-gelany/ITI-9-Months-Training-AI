# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv("D:\ITI\9 Months Training AI\python\Pandas\LAB01\\needed_files\\Top_Scorers_dataset.csv")

# %%
data.shape
# Out:
# (20, 4)

# %%
data.head()
# Out:
#    Rank           Name Nationality  Goals
# 0     1   Alan Shearer     England    260
# 1     2   Wayne Rooney     England    208
# 2     3    Andrew Cole     England    187
# 3     4  Sergio Agüero   Argentina    184
# 4     5  Frank Lampard     England    177

# %%
data.describe()
# Out:
#            Rank       Goals
# count  20.00000   20.000000
# mean   10.50000  156.150000
# std     5.91608   36.245181
# min     1.00000  113.000000
# 25%     5.75000  125.750000
# 50%    10.50000  149.500000
# 75%    15.25000  175.500000
# max    20.00000  260.000000

# %%
stats=pd.read_json("D:\ITI\9 Months Training AI\python\Pandas\LAB01\\needed_files\players_stats.json")

# %%
stats.shape
# Out:
# (21, 9)

# %%
stats.head()
# Out:
#             Name  Height_cm  Appearances  Wins  Losses  Goals_per_match  \
# 0   Michael Owen        173          326   142      95             0.46
# 1  Jermain Defoe        171          496   185     188             0.33
# 2     Harry Kane        188          245   136      57             0.68
# 3  Mohamed Salah        175          158   107      21             0.61
# 4  Romelu Lukaku        190          252   112      80             0.45
#
#    Assists  Yellow_cards  Red_cards
# 0       31            10          1
# 1       33            40          2
# 2       34            27          0
# 3       34             4          0
# 4       35            19          0

# %%
stats.describe()
# Out:
#         Height_cm  Appearances        Wins      Losses  Goals_per_match  \
# count   21.000000    21.000000   21.000000   21.000000        21.000000
# mean   180.190476   358.000000  175.142857   96.857143         0.453810
# std      5.582285   109.827592   60.527090   38.241712         0.129363
# min    171.000000   158.000000  103.000000   21.000000         0.240000
# 25%    176.000000   275.000000  138.000000   80.000000         0.350000
# 50%    180.000000   351.000000  164.000000  103.000000         0.440000
# 75%    184.000000   418.000000  186.000000  119.000000         0.510000
# max    190.000000   609.000000  349.000000  188.000000         0.680000
#
#           Assists  Yellow_cards  Red_cards
# count   21.000000     21.000000  21.000000
# mean    55.714286     34.571429   1.904762
# std     22.886989     22.182361   1.670472
# min     31.000000      4.000000   0.000000
# 25%     37.000000     21.000000   1.000000
# 50%     49.000000     30.000000   2.000000
# ...

# %%
full_data=pd.merge(data,stats,on='Name')

# %%
full_data.head()
# Out:
#    Rank           Name Nationality  Goals  Height_cm  Appearances  Wins  \
# 0     1   Alan Shearer     England    260        183          441   203
# 1     2   Wayne Rooney     England    208        176          491   284
# 2     3    Andrew Cole     England    187        178          414   206
# 3     4  Sergio Agüero   Argentina    184        173          275   186
# 4     5  Frank Lampard     England    177        184          609   349
#
#    Losses  Goals_per_match  Assists  Yellow_cards  Red_cards
# 0     129             0.59       64            41          2
# 1     103             0.42      103           102          3
# 2     106             0.45       73            40          6
# 3      45             0.67       47            23          1
# 4     127             0.29      102            59          2

# %%
full_data.shape
# Out:
# (20, 12)

# %%
plt.figure(figsize=(10,6))
plt.scatter(full_data['Appearances'], full_data['Goals'])
plt.title('Goals vs Games Played')
plt.xlabel('Games Played')
plt.ylabel('Goals')
plt.show()
