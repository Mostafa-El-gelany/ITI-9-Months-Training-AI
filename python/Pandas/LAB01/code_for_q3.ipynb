# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("D:\ITI\9 Months Training AI\python\Pandas\LAB01\\needed_files\WA_Fn-UseC_-Telco-Customer-Churn.csv",index_col='customerID')

# %%
data.head()
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
# ...

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7037 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7040 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
data.head()
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
# ...

# %%
data.TotalCharges=pd.to_numeric(data.TotalCharges,errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7037 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7040 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
data[data.TotalCharges.isnull()]=data.TotalCharges.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16472\144674707.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2283.3004408418656' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data[data.TotalCharges.isnull()]=data.TotalCharges.mean()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16472\144674707.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2283.3004408418656' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data[data.TotalCharges.isnull()]=data.TotalCharges.mean()

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        3.728284    35.937286       68.263141   2283.300441
# std        90.166397    92.213098       92.627199   2265.000258
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.650000    402.225000
# 50%         0.000000    29.000000       70.400000   1400.550000
# 75%         0.000000    56.000000       89.925000   3786.600000
# max      2283.300441  2283.300441     2283.300441   8684.800000

# %%
data.head()
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 7795-CFOCW    Male            0.0      No         No    45.0           No
# 9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7037 non-null   object
#  1   SeniorCitizen     7043 non-null   float64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   float64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7040 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
data
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 7795-CFOCW    Male            0.0      No         No    45.0           No
# 9237-HQITU  Female            0.0      No         No     2.0          Yes
# ...            ...            ...     ...        ...     ...          ...
# 6840-RESVB    Male            0.0     Yes        Yes    24.0          Yes
# 2234-XADUH  Female            0.0     Yes        Yes    72.0          Yes
# 4801-JZAZL  Female            0.0     Yes        Yes    11.0           No
# 8361-LTMKD    Male            1.0     Yes         No     4.0          Yes
# 3186-AJIEK    Male            0.0      No         No    66.0          Yes
#
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data[data.columns[0]].value_counts()
# Out:
# gender
# Male           3530
# Female         3474
# 2283.300441       1
# Name: count, dtype: int64

# %%
data[(data.gender!='Male') & (data.gender!= 'Female')]
# Out:
#                  gender  SeniorCitizen      Partner   Dependents       tenure  \
# customerID
# 6388-TABGU          NaN       0.000000           No          Yes    62.000000
# 4472-LVYGI  2283.300441    2283.300441  2283.300441  2283.300441  2283.300441
# 9470-RTWDV          NaN       0.000000          Yes          Yes    26.000000
# 5884-FBCTL          NaN       0.000000          Yes          Yes    72.000000
# 4223-WOZCM          NaN       1.000000           No           No     2.000000
# 6195-MELTI          NaN       0.000000           No           No    57.000000
# 5324-KTGCG          NaN       0.000000          Yes           No    71.000000
#
#            PhoneService MultipleLines InternetService       OnlineSecurity  \
# customerID
# 6388-TABGU          Yes            No             DSL                  Yes
# 4472-LVYGI  2283.300441   2283.300441     2283.300441          2283.300441
# 9470-RTWDV          Yes           Yes             DSL                   No
# ...

# %%
data= data[(data.gender=='Male') | (data.gender== 'Female')]

# %%
data[(data.gender!='Male') & (data.gender!= 'Female')]
# Out:
# Empty DataFrame
# Columns: [gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []

# %%
data[data.columns[1]].value_counts()
# Out:
# SeniorCitizen
# 0.0    5864
# 1.0    1140
# Name: count, dtype: int64

# %%
data[data.columns[2]].value_counts()
# Out:
# Partner
# No     3614
# Yes    3390
# Name: count, dtype: int64

# %%
data[data.isna().any(axis=1)]
# Out:
#            gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 5575-GNVDE   Male            0.0      No         No    34.0          Yes
# 9896-UYMIE   Male            0.0      No         No    66.0          Yes
# 7931-PXHFC   Male            0.0      No         No    38.0          Yes
# 3186-AJIEK   Male            0.0      No         No    66.0          Yes
#
#            MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 5575-GNVDE            No             DSL            Yes           No
# 9896-UYMIE           Yes             NaN            Yes          Yes
# 7931-PXHFC            No             NaN             No           No
# 3186-AJIEK            No             NaN            Yes           No
#
#            DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# customerID
# 5575-GNVDE              Yes          No          No              No  One year
# ...

# %%
data[data.columns[3]].value_counts()
# Out:
# Dependents
# No     4908
# Yes    2096
# Name: count, dtype: int64

# %%
data[data.columns[4]].value_counts()
# Out:
# tenure
# 1.0     591
# 72.0    361
# 2.0     237
# 3.0     200
# 4.0     176
#        ...
# 38.0     59
# 28.0     57
# 39.0     56
# 44.0     51
# 36.0     50
# Name: count, Length: 72, dtype: int64

# %%
data[data.columns[5]].value_counts()
# Out:
# PhoneService
# Yes    6324
# No      680
# Name: count, dtype: int64

# %%
data[data.columns[6]].value_counts()
# Out:
# MultipleLines
# No                  3359
# Yes                 2965
# No phone service     680
# Name: count, dtype: int64

# %%
data[data.columns[7]].value_counts()
# Out:
# InternetService
# Fiber optic    3088
# DSL            2409
# No             1504
# Name: count, dtype: int64

# %%
data[data.columns[8]].value_counts()
# Out:
# OnlineSecurity
# No                     3486
# Yes                    2014
# No internet service    1504
# Name: count, dtype: int64

# %%
data[data.columns[9]].value_counts()
# Out:
# OnlineBackup
# No                     3077
# Yes                    2423
# No internet service    1504
# Name: count, dtype: int64

# %%
data[data.columns[10]].value_counts()
# Out:
# DeviceProtection
# No                     3084
# Yes                    2416
# No internet service    1504
# Name: count, dtype: int64

# %%
data[data.columns[11]].value_counts()
# Out:
# TechSupport
# No                     3462
# Yes                    2038
# No internet service    1504
# Name: count, dtype: int64

# %%
data[data.columns[12]].value_counts()
# Out:
# StreamingTV
# No                     2798
# Yes                    2702
# No internet service    1504
# Name: count, dtype: int64

# %%
data[data.columns[13]].value_counts()
# Out:
# StreamingMovies
# No                     2770
# Yes                    2730
# No internet service    1504
# Name: count, dtype: int64

# %%
data[data.columns[14]].value_counts()
# Out:
# Contract
# Month-to-month    3852
# Two year          1684
# One year          1468
# Name: count, dtype: int64

# %%
data[data.columns[15]].value_counts()
# Out:
# PaperlessBilling
# Yes    4156
# No     2848
# Name: count, dtype: int64

# %%
data[data.columns[16]].value_counts()
# Out:
# PaymentMethod
# Electronic check             2358
# Mailed check                 1585
# Bank transfer (automatic)    1540
# Credit card (automatic)      1520
# Name: count, dtype: int64

# %%
data[data.columns[17]].value_counts()
# Out:
# MonthlyCharges
# 20.05     59
# 19.85     44
# 19.95     44
# 19.90     43
# 19.70     42
#           ..
# 23.65      1
# 114.70     1
# 43.65      1
# 87.80      1
# 78.70      1
# Name: count, Length: 1584, dtype: int64

# %%
data[data.columns[18]].value_counts()
# Out:
# TotalCharges
# 19.75      9
# 20.20      8
# 19.90      7
# 19.65      7
# 20.25      6
#           ..
# 692.35     1
# 130.15     1
# 3211.90    1
# 7843.55    1
# 6844.50    1
# Name: count, Length: 6524, dtype: int64

# %%
data[data.columns[19]].value_counts()
# Out:
# Churn
# No     5144
# Yes    1856
# Name: count, dtype: int64

# %%
data.dropna(inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16472\1368182302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)

# %%
data.drop_duplicates(inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16472\2282015914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop_duplicates(inplace=True)

# %%
data.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7000 entries, 7590-VHVEG to 8361-LTMKD
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7000 non-null   object
#  1   SeniorCitizen     7000 non-null   float64
#  2   Partner           7000 non-null   object
#  3   Dependents        7000 non-null   object
#  4   tenure            7000 non-null   float64
#  5   PhoneService      7000 non-null   object
#  6   MultipleLines     7000 non-null   object
#  7   InternetService   7000 non-null   object
#  8   OnlineSecurity    7000 non-null   object
#  9   OnlineBackup      7000 non-null   object
#  10  DeviceProtection  7000 non-null   object
#  11  TechSupport       7000 non-null   object
#  12  StreamingTV       7000 non-null   object
#  13  StreamingMovies   7000 non-null   object
#  14  Contract          7000 non-null   object
#  15  PaperlessBilling  7000 non-null   object
# ...

# %%
data_encoded = pd.get_dummies(data,columns=['gender', 'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'PaperlessBilling', 'PaymentMethod'], drop_first=True)

# %%
data_encoded.columns
# Out:
# Index(['SeniorCitizen', 'tenure', 'Contract', 'MonthlyCharges', 'TotalCharges',
#        'Churn', 'gender_Male', 'Partner_Yes', 'Dependents_Yes',
#        'PhoneService_Yes', 'MultipleLines_No phone service',
#        'MultipleLines_Yes', 'InternetService_Fiber optic',
#        'InternetService_No', 'OnlineSecurity_No internet service',
#        'OnlineSecurity_Yes', 'OnlineBackup_No internet service',
#        'OnlineBackup_Yes', 'DeviceProtection_No internet service',
#        'DeviceProtection_Yes', 'TechSupport_No internet service',
#        'TechSupport_Yes', 'StreamingTV_No internet service', 'StreamingTV_Yes',
#        'StreamingMovies_No internet service', 'StreamingMovies_Yes',
#        'PaperlessBilling_Yes', 'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
contact_encoder={ "Month-to-month" : 1, "One year" : 2, "Two year" : 3 }
data_encoded['Contract']=data_encoded['Contract'].map(contact_encoder)

# %%
data_encoded.Contract.value_counts()
# Out:
# Contract
# 1    3852
# 3    1683
# 2    1465
# Name: count, dtype: int64

# %%
data_encoded.Contract=pd.to_numeric(data_encoded.Contract)

# %%
data_encoded[~data_encoded.Contract.isin([1,2,3])]
# Out:
# Empty DataFrame
# Columns: [SeniorCitizen, tenure, Contract, MonthlyCharges, TotalCharges, Churn, gender_Male, Partner_Yes, Dependents_Yes, PhoneService_Yes, MultipleLines_No phone service, MultipleLines_Yes, InternetService_Fiber optic, InternetService_No, OnlineSecurity_No internet service, OnlineSecurity_Yes, OnlineBackup_No internet service, OnlineBackup_Yes, DeviceProtection_No internet service, DeviceProtection_Yes, TechSupport_No internet service, TechSupport_Yes, StreamingTV_No internet service, StreamingTV_Yes, StreamingMovies_No internet service, StreamingMovies_Yes, PaperlessBilling_Yes, PaymentMethod_Credit card (automatic), PaymentMethod_Electronic check, PaymentMethod_Mailed check]
# Index: []
#
# [0 rows x 30 columns]

# %%
churn_encoder={ "Yes" : 1, "No" : 0 }
data_encoded['Churn']=data_encoded['Churn'].map(churn_encoder)

# %%
data_encoded.Contract=pd.to_numeric(data_encoded.Contract)

# %%
data_encoded[~data_encoded.Churn.isin([0,1])]
# Out:
# Empty DataFrame
# Columns: [SeniorCitizen, tenure, Contract, MonthlyCharges, TotalCharges, Churn, gender_Male, Partner_Yes, Dependents_Yes, PhoneService_Yes, MultipleLines_No phone service, MultipleLines_Yes, InternetService_Fiber optic, InternetService_No, OnlineSecurity_No internet service, OnlineSecurity_Yes, OnlineBackup_No internet service, OnlineBackup_Yes, DeviceProtection_No internet service, DeviceProtection_Yes, TechSupport_No internet service, TechSupport_Yes, StreamingTV_No internet service, StreamingTV_Yes, StreamingMovies_No internet service, StreamingMovies_Yes, PaperlessBilling_Yes, PaymentMethod_Credit card (automatic), PaymentMethod_Electronic check, PaymentMethod_Mailed check]
# Index: []
#
# [0 rows x 30 columns]

# %%
target_data=data_encoded
target_data=target_data.Churn

# %%
target_data
# Out:
# customerID
# 7590-VHVEG    0
# 3668-QPYBK    1
# 7795-CFOCW    0
# 9237-HQITU    1
# 9305-CDSKC    1
#              ..
# 2569-WGERO    0
# 6840-RESVB    0
# 2234-XADUH    0
# 4801-JZAZL    0
# 8361-LTMKD    1
# Name: Churn, Length: 7000, dtype: int64

# %%
data_encoded
# Out:
#             SeniorCitizen  tenure  Contract  MonthlyCharges  TotalCharges  \
# customerID
# 7590-VHVEG            0.0     1.0         1           29.85         29.85
# 3668-QPYBK            0.0     2.0         1           53.85        108.15
# 7795-CFOCW            0.0    45.0         2           42.30       1840.75
# 9237-HQITU            0.0     2.0         1           70.70        151.65
# 9305-CDSKC            0.0     8.0         1           99.65        820.50
# ...                   ...     ...       ...             ...           ...
# 2569-WGERO            0.0    72.0         3           21.15       1419.40
# 6840-RESVB            0.0    24.0         2           84.80       1990.50
# 2234-XADUH            0.0    72.0         2          103.20       7362.90
# 4801-JZAZL            0.0    11.0         1           29.60        346.45
# 8361-LTMKD            1.0     4.0         1           74.40        306.60
#
# ...

# %%
data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7000 entries, 7590-VHVEG to 8361-LTMKD
# Data columns (total 29 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   SeniorCitizen                          7000 non-null   float64
#  1   tenure                                 7000 non-null   float64
#  2   Contract                               7000 non-null   int64
#  3   MonthlyCharges                         7000 non-null   float64
#  4   TotalCharges                           7000 non-null   float64
#  5   gender_Male                            7000 non-null   bool
#  6   Partner_Yes                            7000 non-null   bool
#  7   Dependents_Yes                         7000 non-null   bool
#  8   PhoneService_Yes                       7000 non-null   bool
#  9   MultipleLines_No phone service         7000 non-null   bool
# ...

# %%
data_encoded.drop(columns=['Churn'],inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data_encoded[['tenure','MonthlyCharges','TotalCharges']] = scaler.fit_transform(data_encoded[['tenure','MonthlyCharges','TotalCharges']])

# %%
data_encoded.to_csv("D:\\ITI\\9 Months Training AI\\python\\Pandas\\LAB01\\final-training-data.csv")

# %%
target_data.to_csv("D:\\ITI\\9 Months Training AI\\python\\Pandas\\LAB01\\final-target-data.csv")
